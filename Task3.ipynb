# %% [markdown]
# OASIS INFOBYTE INTERNSHIP
#
# **TASK:3 CAR PRICE PREDICTION WITH MACHINE LEARNING**
#
# BY:*Vaishnavi Jadhav*  |  Email: vaishnavisj123@gmail.com

# %% [markdown]
# # **Importing the necessary libraries:**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn import metrics
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## **Load The Dataset**

# %%
cars_price=pd.read_csv('car data.csv')

# %%
print(cars_price)
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Selling_type Transmission  Owner
# 0         Dealer       Manual      0
# 1         Dealer       Manual      0
# 2         Dealer       Manual      0
# 3         Dealer       Manual      0
# 4         Dealer       Manual      0
# ..           ...          ...    ...
# 296       Dealer       Manual      0
# 297       Dealer       Manual      0
# 298       Dealer       Manual      0
# 299       Dealer       Manual      0
# 300       Dealer       Manual      0
#
# [301 rows x 9 columns]

# %%
cars_price.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Selling_type Transmission  Owner
# 0       Dealer       Manual      0
# 1       Dealer       Manual      0
# 2       Dealer       Manual      0
# 3       Dealer       Manual      0
# 4       Dealer       Manual      0

# %%
cars_price.tail()
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 296     city  2016           9.50           11.6       33988    Diesel
# 297     brio  2015           4.00            5.9       60000    Petrol
# 298     city  2009           3.35           11.0       87934    Petrol
# 299     city  2017          11.50           12.5        9000    Diesel
# 300     brio  2016           5.30            5.9        5464    Petrol
#
#     Selling_type Transmission  Owner
# 296       Dealer       Manual      0
# 297       Dealer       Manual      0
# 298       Dealer       Manual      0
# 299       Dealer       Manual      0
# 300       Dealer       Manual      0

# %%
cars_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Driven_kms     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Selling_type   301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
cars_price.describe()
# Out:
#               Year  Selling_Price  Present_Price     Driven_kms       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.642584   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %% [markdown]
# ## **Check Each Column**

# %%
cars_price.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Driven_kms',
#        'Fuel_Type', 'Selling_type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
cars_price.nunique()
# Out:
# Car_Name          98
# Year              16
# Selling_Price    156
# Present_Price    148
# Driven_kms       206
# Fuel_Type          3
# Selling_type       2
# Transmission       2
# Owner              3
# dtype: int64

# %%
cars_price['Car_Name'].unique()
# Out:
# array(['ritz', 'sx4', 'ciaz', 'wagon r', 'swift', 'vitara brezza',
#        's cross', 'alto 800', 'ertiga', 'dzire', 'alto k10', 'ignis',
#        '800', 'baleno', 'omni', 'fortuner', 'innova', 'corolla altis',
#        'etios cross', 'etios g', 'etios liva', 'corolla', 'etios gd',
#        'camry', 'land cruiser', 'Royal Enfield Thunder 500',
#        'UM Renegade Mojave', 'KTM RC200', 'Bajaj Dominar 400',
#        'Royal Enfield Classic 350', 'KTM RC390', 'Hyosung GT250R',
#        'Royal Enfield Thunder 350', 'KTM 390 Duke ',
#        'Mahindra Mojo XT300', 'Bajaj Pulsar RS200',
#        'Royal Enfield Bullet 350', 'Royal Enfield Classic 500',
#        'Bajaj Avenger 220', 'Bajaj Avenger 150', 'Honda CB Hornet 160R',
#        'Yamaha FZ S V 2.0', 'Yamaha FZ 16', 'TVS Apache RTR 160',
#        'Bajaj Pulsar 150', 'Honda CBR 150', 'Hero Extreme',
#        'Bajaj Avenger 220 dtsi', 'Bajaj Avenger 150 street',
#        'Yamaha FZ  v 2.0', 'Bajaj Pulsar  NS 200', 'Bajaj Pulsar 220 F',
#        'TVS Apache RTR 180', 'Hero Passion X pro', 'Bajaj Pulsar NS 200',
#        'Yamaha Fazer ', 'Honda Activa 4G', 'TVS Sport ',
#        'Honda Dream Yuga ', 'Bajaj Avenger Street 220',
#        'Hero Splender iSmart', 'Activa 3g', 'Hero Passion Pro',
#        'Honda CB Trigger', 'Yamaha FZ S ', 'Bajaj Pulsar 135 LS',
#        'Activa 4g', 'Honda CB Unicorn', 'Hero Honda CBZ extreme',
#        'Honda Karizma', 'Honda Activa 125', 'TVS Jupyter',
#        'Hero Honda Passion Pro', 'Hero Splender Plus', 'Honda CB Shine',
#        'Bajaj Discover 100', 'Suzuki Access 125', 'TVS Wego',
#        'Honda CB twister', 'Hero Glamour', 'Hero Super Splendor',
#        'Bajaj Discover 125', 'Hero Hunk', 'Hero  Ignitor Disc',
#        'Hero  CBZ Xtreme', 'Bajaj  ct 100', 'i20', 'grand i10', 'i10',
#        'eon', 'xcent', 'elantra', 'creta', 'verna', 'city', 'brio',
#        'amaze', 'jazz'], dtype=object)

# %%
cars_price['Fuel_Type'].unique()
# Out:
# array(['Petrol', 'Diesel', 'CNG'], dtype=object)

# %%
cars_price['Year'].unique()
# Out:
# array([2014, 2013, 2017, 2011, 2018, 2015, 2016, 2009, 2010, 2012, 2003,
#        2008, 2006, 2005, 2004, 2007])

# %%
cars_price['Selling_Price'].unique()
# Out:
# array([ 3.35,  4.75,  7.25,  2.85,  4.6 ,  9.25,  6.75,  6.5 ,  8.75,
#         7.45,  6.85,  7.5 ,  6.1 ,  2.25,  7.75,  3.25,  2.65,  4.9 ,
#         4.4 ,  2.5 ,  2.9 ,  3.  ,  4.15,  6.  ,  1.95,  3.1 ,  2.35,
#         4.95,  5.5 ,  2.95,  4.65,  0.35,  5.85,  2.55,  1.25,  1.05,
#         5.8 , 14.9 , 23.  , 18.  , 16.  ,  2.75,  3.6 ,  4.5 ,  4.1 ,
#        19.99,  6.95, 18.75, 23.5 , 33.  , 19.75,  4.35, 14.25,  3.95,
#         1.5 ,  5.25, 14.5 , 14.73, 12.5 ,  3.49, 35.  ,  5.9 ,  3.45,
#         3.8 , 11.25,  3.51,  4.  , 20.75, 17.  ,  7.05,  9.65,  1.75,
#         1.7 ,  1.65,  1.45,  1.35,  1.2 ,  1.15,  1.11,  1.1 ,  1.  ,
#         0.95,  0.9 ,  0.75,  0.8 ,  0.78,  0.72,  0.65,  0.6 ,  0.55,
#         0.52,  0.51,  0.5 ,  0.48,  0.45,  0.42,  0.4 ,  0.38,  0.31,
#         0.3 ,  0.27,  0.25,  0.2 ,  0.18,  0.17,  0.16,  0.15,  0.12,
#         0.1 ,  5.75,  5.15,  7.9 ,  4.85, 11.75,  3.15,  6.45,  3.5 ,
#         8.25,  5.11,  2.7 ,  6.15, 11.45,  3.9 ,  9.1 ,  4.8 ,  2.  ,
#         5.35,  6.25,  5.95,  5.2 ,  3.75, 12.9 ,  5.  ,  5.4 ,  7.2 ,
#        10.25,  8.5 ,  8.4 ,  9.15,  6.6 ,  3.65,  8.35,  6.7 ,  5.3 ,
#        10.9 ,  8.65,  9.7 ,  2.1 ,  8.99,  7.4 ,  5.65, 10.11,  6.4 ,
#         8.55,  9.5 , 11.5 ])

# %%
cars_price['Driven_kms'].unique()
# Out:
# array([ 27000,  43000,   6900,   5200,  42450,   2071,  18796,  33429,
#         20273,  42367,   2135,  51000,  15000,  26000,  77427,  41678,
#         35500,  41442,  25000,   2400,  50000,  45280,  56879,  20000,
#         55138,  16200,  44542,  45000,  51439,  54200,  39000,  49998,
#         48767, 127000,  10079,  62000,  24524,  46706,  58000,  45780,
#         64532,  65000,  25870,  37000, 104707,  40000, 135000,  90000,
#         70000,  40534,  39485,  41000,  40001,  40588,  78000,  47000,
#          6000,  11000,  59000,  88000,  12000,  71000,  56001,  83000,
#         36000,  72000, 135154,  80000,  89000,  23000,  38000, 197176,
#        142000,  56000,  58242,  75000,  29000,   8700,  50024,   3000,
#          1400,   4000,   1200,   4100,  21700,  16500,  18000,   7000,
#         35000,  17000,  17500,  33000,  14000,   5400,   5700,  46500,
#         11500,   1300,   5000,   3500,    500,  11800,  23500,  16000,
#         16600,  32000,  19000,  24000,  31000,  13000,   8000,   4300,
#          8600,  14500,   1000,  42000,   5500,   6700,  13700,  38600,
#         30000, 213000,  60000,  21000,   1900,  22000,  55000,  49000,
#        500000,  53000,  92233,  28200,  53460,  28282,   3493,  12479,
#         34797,   3435,  21125,  35775,  43535,  22671,  31604,  20114,
#         36100,  12500,  45078,  38488,  77632,  61381,  36198,  22517,
#         24678,  57000,  52132,  15001,  12900,   4492,  15141,  11849,
#         68000,  60241,  23709,  32322,  35866,  34000,  35934,  56701,
#         31427,  48000,  54242,  53675,  49562,  40324,  36054,  29223,
#          5600,  40023,  16002,  40026,  21200,  19434,  18828,  69341,
#         69562,  27600,  61203,  30753,  24800,  21780,  40126,  14465,
#         50456,  63000,   9010,   9800,  15059,  28569,  44000,  10980,
#         33019,  60076,  33988,  87934,   9000,   5464])

# %% [markdown]
# ## **Null & Duplicated Values**

# %%
cars_price.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Driven_kms       0
# Fuel_Type        0
# Selling_type     0
# Transmission     0
# Owner            0
# dtype: int64

# %%
cars_price.duplicated().sum()
# Out:
# np.int64(2)

# %%
cars_price.drop_duplicates(inplace=True)

# %%
cars_price.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## **DataTypes**

# %%
cars_price.dtypes
# Out:
# Car_Name          object
# Year               int64
# Selling_Price    float64
# Present_Price    float64
# Driven_kms         int64
# Fuel_Type         object
# Selling_type      object
# Transmission      object
# Owner              int64
# dtype: object

# %% [markdown]
# ## **checking the distribution of categorical data**

# %%
cars_price['Fuel_Type'].value_counts()
# Out:
# Fuel_Type
# Petrol    239
# Diesel     58
# CNG         2
# Name: count, dtype: int64

# %%
cars_price['Transmission'].value_counts()
# Out:
# Transmission
# Manual       260
# Automatic     39
# Name: count, dtype: int64

# %%
cars_price['Owner'].value_counts()
# Out:
# Owner
# 0    288
# 1     10
# 3      1
# Name: count, dtype: int64

# %% [markdown]
# # Encoding the data

# %%
cars_price['Fuel_Type'].replace({'Petrol':0,'Diesel':1,'CNG':2},inplace=True)

# %%
cars_price['Transmission'].replace({'Manual':0,'Automatic':1},inplace=True)

# %%
cars_price['Selling_type'].replace({'Dealer':0,'Individual':1},inplace=True)

# %%
cars_price.head(5)
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Driven_kms  Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000          0
# 1      sx4  2013           4.75           9.54       43000          1
# 2     ciaz  2017           7.25           9.85        6900          0
# 3  wagon r  2011           2.85           4.15        5200          0
# 4    swift  2014           4.60           6.87       42450          1
#
#    Selling_type  Transmission  Owner
# 0             0             0      0
# 1             0             0      0
# 2             0             0      0
# 3             0             0      0
# 4             0             0      0

# %%
##Renaming 'Selling_type' column to 'Seller_Type' for a better understanding :
cars_price.rename(columns = {'Selling_type':'Seller_Type'}, inplace = True)

# %% [markdown]
# ## **Splitting The Data and Target**

# %%
X = cars_price.drop(['Car_Name', 'Selling_Price'], axis = 1)
Y = cars_price['Selling_Price']

# %%
X.head()
# Out:
#    Year  Present_Price  Driven_kms  Fuel_Type  Seller_Type  Transmission  \
# 0  2014           5.59       27000          0            0             0
# 1  2013           9.54       43000          1            0             0
# 2  2017           9.85        6900          0            0             0
# 3  2011           4.15        5200          0            0             0
# 4  2014           6.87       42450          1            0             0
#
#    Owner
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0

# %%
Y.head()
# Out:
# 0    3.35
# 1    4.75
# 2    7.25
# 3    2.85
# 4    4.60
# Name: Selling_Price, dtype: float64

# %% [markdown]
# ## **Splitting Training and Testing data**

# %% [markdown]
# X train : All the training data
#
# X test : All the testing data
#
# Y train : All the prices of X train
#
# Y test : All the prices of X test

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.1, random_state=2)

# %% [markdown]
# ## **Model Training**

# %% [markdown]
# # Linear regression

# %%
lin_reg = LinearRegression()
lin_reg.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# #### **Model Evaluation**

# %% [markdown]
# ##### **A. Evaluation on Training Data**

# %%
# Predicting on Training data:
training_data_prediction = lin_reg.predict(X_train)

# R Squared error:
score_of_error = metrics.r2_score(Y_train, training_data_prediction)
print(f"The R square error in this case is : {score_of_error}")
# Out:
# The R square error in this case is : 0.8768029664697252

# %% [markdown]
# **Actual VS Prdeicted Values**

# %%
# Creating a DataFrame for plotting
plot_data = {'Actual Price': Y_train, 'Predicted Price': training_data_prediction}
df = pd.DataFrame(plot_data)

# Creating a scatter plot
fig = px.scatter(df, x='Actual Price', y='Predicted Price', color=df.index,
                 title='Actual Prices vs Predicted Prices',
                 labels={'Actual Price': 'Actual Price', 'Predicted Price': 'Predicted Price'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1a397dc3-d440-43f1-ab77-ebe3f7aab571" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1a397dc3-d440-43f1-ab77-ebe3f7aab571")) {                    Plotly.newPlot(                        "1a397dc3-d440-43f1-ab77-ebe3f7aab571",                        [{"hovertemplate":"Actual Price=%{x}\u003cbr\u003ePredicted Price=%{y}\u003cbr\u003eindex=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[154,67,245,239,90,275,159,105,128,224,11,226,166,129,176,75,190,241,285,158,133,101,10,85,144,66,120,284,111,207,54,174,24,100,246,122,155,194,227,203,55,4,153,251,165,146,211,229,25,280,108,206,21,29,286,157,72,279,221,130,65,14,116,19,86,299,132,26,267,201,191,218,70,168,114,45,6,149,12,95,103,180,115,5,156,2,80,68,193,117,163,178,119,173,287,161,234,247,283,177,142,91,252,9,38,298,46,171,282,297,258,49,43,242,58,147,124,294,277,271,182,186,205,1,141,113,276,237,109,8,225,281,196,22,278,233,291,121,261,293,184,79,259,47,110,243,264,232,83,195,137,268,256,292,199,37,94,188,295,63,0,28,102,179,189,222,150,64,40,248,160,145,18,60,167,217,238,230,210,219,151,125,56,16,202,204,270,260,152,88,255,214,148,99,127,236,62,82,300,69,131,212,57,20,200,87,71,231,139,61,35,41,140,77,263,244,27,33,44,98,84,192,266,254,112,107,187,74,250,249,235,138,50,209,288,134,51,240,53,81,32,123,213,198,89,257,59,34,39,52,262,104,197,169,118,126,220,289,48,215,296,97,164,265,76,23,73,15,170],"coloraxis":"coloraxis","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[0.5,9.25,5.2,2.0,3.8,10.9,0.45,1.35,0.8,5.11,6.85,5.25,0.45,0.78,0.35,3.95,0.2,4.75,7.4,0.48,0.72,1.7,2.85,2.5,0.6,19.75,1.05,3.5,1.15,5.15,2.75,0.38,2.9,1.75,3.75,1.05,0.48,0.2,2.55,2.95,3.6,4.6,0.5,5.0,0.45,0.55,11.75,3.1,3.0,5.25,1.2,5.75,4.9,7.45,5.65,0.48,7.45,6.25,4.5,0.75,4.75,2.25,1.1,2.65,35.0,11.5,0.75,4.15,8.35,3.25,0.2,6.45,3.95,0.42,1.15,7.5,6.75,0.51,7.5,5.85,1.45,0.3,1.11,9.25,0.48,7.25,14.73,4.35,0.2,1.1,0.45,0.35,1.05,0.4,5.75,0.45,5.5,5.95,8.99,0.35,0.6,11.25,5.4,7.45,3.0,3.35,2.65,0.4,8.25,4.0,8.4,7.75,5.5,4.4,4.1,0.55,0.95,3.75,9.7,3.0,0.3,0.25,5.25,4.75,0.6,1.15,8.65,11.25,1.2,8.75,2.7,2.1,0.17,4.4,6.0,3.9,5.4,1.05,5.5,3.25,0.25,14.5,3.9,1.05,1.2,6.25,4.0,11.45,12.5,0.18,0.65,4.8,10.25,6.4,0.12,0.35,4.0,0.25,8.55,23.5,3.35,1.95,1.65,0.31,0.2,6.0,0.5,33.0,5.85,4.0,0.45,0.6,3.25,6.95,0.42,3.15,4.8,6.15,3.1,4.5,0.5,0.9,4.5,7.25,4.4,2.75,4.1,9.15,0.5,3.45,3.0,5.25,0.52,9.65,0.75,3.1,18.75,23.0,5.3,14.25,0.75,11.25,4.75,2.85,0.1,5.9,4.5,9.25,0.6,4.5,2.95,2.55,0.6,1.5,6.6,5.95,6.0,6.0,1.25,7.05,3.49,0.2,3.65,5.25,1.15,1.25,0.25,4.9,12.9,5.25,9.1,0.6,14.9,4.85,8.4,0.65,23.0,5.35,16.0,4.75,4.95,1.0,2.9,0.15,4.75,8.5,19.99,5.5,2.25,18.0,4.0,1.35,0.16,0.4,1.1,0.9,3.5,10.11,5.8,4.5,9.5,17.0,0.45,6.5,5.5,2.5,2.65,7.75,0.4],"xaxis":"x","y":[0.7829375254239039,10.11512563139945,5.952132530488825,2.622430449340527,7.498771681222593,9.560016343991947,3.1704274056223767,1.7600154426274912,1.9872735386910563,6.492248370603647,7.67655116317917,4.359761740139334,1.463059945659893,1.9630172000755692,-0.4441310482706058,4.783761396965133,-1.9229387384301617,4.223382049671841,7.391894824734891,1.810614117845489,1.642624463417519,2.4160070199122856,4.342923442244796,6.2236295824735635,0.7381029989961689,14.283841707739839,1.7510692391811062,3.7424502527686627,1.8406659374606988,5.651917334744439,0.9125573347040472,0.9377414709337017,2.8249911203173497,2.048817868657693,3.6035700743432244,1.7096364265279362,3.1687781317700683,-1.8516074885139915,2.045654360310664,2.1402624761691413,7.2244962743701535,5.778241285092122,0.23439523920148986,5.252765556322288,2.8091739438558534,0.7033448121100037,9.666983995445548,4.902138235412735 ...

# %% [markdown]
# ##### **B. Evaluation on Testing Data**

# %%
# Predicting on Testing data:
test_data_prediction = lin_reg.predict(X_test)

# R Squared Error:
score_of_error = metrics.r2_score(Y_test, test_data_prediction)
print(f"The R Squared error in this case is: {score_of_error}")
# Out:
# The R Squared error in this case is: 0.8561865067080684

# %%
# Creating a DataFrame for plotting
plot_data_test = {'Actual Price': Y_test, 'Predicted Price': test_data_prediction}
df_test = pd.DataFrame(plot_data_test)

# Creating a scatter plot
fig_test = px.scatter(df_test, x='Actual Price', y='Predicted Price', color=df_test.index,
                      title='Actual Prices vs Predicted Prices (Test Set)',
                      labels={'Actual Price': 'Actual Price', 'Predicted Price': 'Predicted Price'})
fig_test.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4804560f-09f2-40c6-a68a-e4e3deb1ef58" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4804560f-09f2-40c6-a68a-e4e3deb1ef58")) {                    Plotly.newPlot(                        "4804560f-09f2-40c6-a68a-e4e3deb1ef58",                        [{"hovertemplate":"Actual Price=%{x}\u003cbr\u003ePredicted Price=%{y}\u003cbr\u003eindex=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[181,223,228,7,175,31,185,183,273,143,13,274,36,272,78,269,208,96,92,216,3,106,30,172,136,42,253,290,135,162],"coloraxis":"coloraxis","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[0.3,8.25,4.95,6.5,0.38,2.35,0.25,0.27,2.25,0.6,6.1,5.3,4.65,7.5,5.25,6.7,7.9,20.75,3.51,2.9,2.85,1.35,3.1,0.4,0.65,1.95,7.2,4.5,0.65,0.45],"xaxis":"x","y":[1.162735797388109,7.186282256701588,6.012605905072178,6.990739536289766,-0.8077784672739199,2.2643856701363347,-0.3308904517995188,0.13647670097827813,2.9858525764268506,1.4593094402808902,5.240992973249604,4.497208027719807,4.890389527395769,6.244466888859392,11.00676295181222,6.292691656299894,6.324953528928063,16.17404987697512,3.681865407804594,4.259077496613486,2.2066579692003643,1.1652601534837004,4.547896208803763,0.645511885428391,0.8391776254595698,2.0612352222998425,7.087108858454144,4.3066483509469435,1.1313009287883915,0.008315244539403466],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.444444444444444 ...
